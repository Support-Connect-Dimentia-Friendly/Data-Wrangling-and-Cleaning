# %%
import pandas as pd

# %% [markdown]
# ## aihw-age-94-data-tables.xlsx file showing alzhimers disease is most popular

# %%
first_df = pd.read_excel (r'aihw-age-94-data-tables.xlsx', sheet_name='wanted')
new_header = first_df.iloc[0] 
first_df = first_df[1:] 
first_df.columns = new_header
first_df.drop([ "Age-standardised rate (per 100,000 population)"], axis = 1, inplace = True) 
first_df = first_df.filter(["Dementia type", "Year", "Number"]) 
first_df = first_df.drop([56, 57,58,59,60])
first_df
# Out:
# 0                       Dementia type     Year Number
# 1                 Alzheimer's disease  2006–07  19203
# 2                                 NaN  2007–08  20005
# 3                                 NaN  2008–09  18677
# 4                                 NaN  2009–10  18169
# 5                                 NaN  2010–11  18542
# 6                                 NaN  2011–12  19133
# 7                                 NaN  2012–13  22229
# 8                                 NaN  2013–14  23399
# 9                                 NaN  2014–15  25414
# 10                                NaN  2015–16  23727
# 11                                NaN  2016–17  25979
# 12                  Vascular dementia  2006–07   6984
# 13                                NaN  2007–08   7509
# 14                                NaN  2008–09   7432
# 15                                NaN  2009–10   7510
# 16                                NaN  2010–11   8101
# ...

# %% [markdown]
# ## State -dementia 2011-2020

# %%
state_dementia_df = pd.read_excel (r'State-Territory-Dementia-2011-2020.xls')

# %%
kk_df = state_dementia_df[2:13]

# %%
new_header_1 = kk_df.iloc[0] #grab the first row for the header
kk_df = kk_df[1:] #take the data less the header row
kk_df.columns = new_header_1 #set the header row as the df header

# %%
kk_df = kk_df.reset_index()

# %%
kk_df = kk_df.drop('index',axis = 1)

# %%
new_header_2 = kk_df.iloc[0] #grab the first row for the header
kk_df = kk_df[1:] #take the data less the header row
kk_df.columns = new_header_2 #set the header row as the df header

# %%
df_2011 = kk_df.iloc[:,[0,1,2,3]]

# %%
df_2011
# Out:
# 0           NaN   Males Females Persons
# 1           NSW   38200   63600  101800
# 2           Vic   28600   47300   75900
# 3           Qld   21500   33300   54700
# 4            WA   10500   16400   26900
# 5            SA    9700   16700   26500
# 6           Tas    2900    4700    7600
# 7           ACT    1400    2200    3600
# 8            NT     500     500    1000
# 9  Australia(b)  113300  184700  298000

# %%
kk_df
# Out:
# 0           NaN   Males Females Persons  NaN   Males Females Persons  NaN  \
# 1           NSW   38200   63600  101800  NaN   39500   65900  105500  NaN
# 2           Vic   28600   47300   75900  NaN   29700   49400   79100  NaN
# 3           Qld   21500   33300   54700  NaN   22700   35200   58000  NaN
# 4            WA   10500   16400   26900  NaN   11100   17300   28400  NaN
# 5            SA    9700   16700   26500  NaN   10100   17400   27500  NaN
# 6           Tas    2900    4700    7600  NaN    3000    4900    7900  NaN
# 7           ACT    1400    2200    3600  NaN    1500    2400    3800  NaN
# 8            NT     500     500    1000  NaN     500     600    1000  NaN
# 9  Australia(b)  113300  184700  298000  NaN  118100  193200  311300  NaN
#
# 0   Males  ... Females Persons  NaN   Males Females Persons  NaN   Males  \
# 1   40900  ...   77000  125200  NaN   49700   78800  128600  NaN   51300
# 2   30700  ...   58200   94600  NaN   37700   59700   97400  NaN   38900
# ...

# %% [markdown]
# ## List of activities with images

# %%
Activity_df = pd.read_excel (r'reminder activities.xlsx')

# %%
Activity_df
# Out:
#     ID              activity  catagory  \
# 0    1      take medication       home
# 1    2          insulin shot      home
# 2    3         feed the pets      home
# 3    4      clean the dishes      home
# 4    5          make the bed      home
# 5    6       clean the house      home
# 6    7  take the rubbish out      home
# 7    8           take a bath      home
# 8    9      grocery shopping      home
# 9   10    read the newspaper      home
# 10  11        lock the doors      home
# 11  12    close the windows       home
# 12  13          brush teath       home
# 13  14        GP appointment  outdoors
# 14  15   dentist appointment  outdoors
# 15  16       go the the park  outdoors
# 16  17        visit a friend  outdoors
# 17  18          walk the dog  outdoors
# 18  19     go out for dinner  outdoors
# 19  20     go to the library  outdoors
#
#                                            image link
# 0   https://www.google.com/url?sa=i&url=https%3A%2...
# ...
